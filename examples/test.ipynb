# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

# Replace 'your_path_here' with the path to your CSV file
file_path = "../data/Traffic_Crashes_-_People.csv"

# Read the CSV file
df1 = pd.read_csv(file_path)

# Display information about the DataFrame
df1.info()
# Out:
# C:\Users\ashee\AppData\Local\Temp\ipykernel_13616\2744668881.py:7: DtypeWarning: Columns (19,23,24,25,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv(file_path)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1955138 entries, 0 to 1955137
# Data columns (total 29 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   PERSON_ID              object
#  1   PERSON_TYPE            object
#  2   CRASH_RECORD_ID        object
#  3   VEHICLE_ID             float64
#  4   CRASH_DATE             object
#  5   SEAT_NO                float64
#  6   CITY                   object
#  7   STATE                  object
#  8   ZIPCODE                object
#  9   SEX                    object
#  10  AGE                    float64
#  11  DRIVERS_LICENSE_STATE  object
#  12  DRIVERS_LICENSE_CLASS  object
#  13  SAFETY_EQUIPMENT       object
#  14  AIRBAG_DEPLOYED        object
# ...

# %%
# Convert date column
df1['CRASH_DATE'] = pd.to_datetime(df1['CRASH_DATE'], errors='coerce')

# Convert integer columns with missing values to nullable integer type
df1['VEHICLE_ID'] = df1['VEHICLE_ID'].astype('Int64')
df1['SEAT_NO'] = df1['SEAT_NO'].astype('Int64')
df1['AGE'] = df1['AGE'].astype('Int64')

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1955138 entries, 0 to 1955137
# Data columns (total 29 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   PERSON_ID              object
#  1   PERSON_TYPE            object
#  2   CRASH_RECORD_ID        object
#  3   VEHICLE_ID             Int64
#  4   CRASH_DATE             datetime64[ns]
#  5   SEAT_NO                Int64
#  6   CITY                   object
#  7   STATE                  object
#  8   ZIPCODE                object
#  9   SEX                    object
#  10  AGE                    Int64
#  11  DRIVERS_LICENSE_STATE  object
#  12  DRIVERS_LICENSE_CLASS  object
#  13  SAFETY_EQUIPMENT       object
#  14  AIRBAG_DEPLOYED        object
#  15  EJECTION               object
#  16  INJURY_CLASSIFICATION  object
#  17  HOSPITAL               object
#  18  EMS_AGENCY             object
#  19  EMS_RUN_NO             object
#  20  DRIVER_ACTION          object
# ...

# %%
transformedDf1 = df1[[
      "PERSON_ID",
      "CRASH_RECORD_ID",
      "SEX",
      "AGE",
      "SAFETY_EQUIPMENT",
      "INJURY_CLASSIFICATION",
      "BAC_RESULT"
    ]]
transformedDf1.head()
# Out:
#   PERSON_ID                                    CRASH_RECORD_ID SEX   AGE  \
# 0   O749947  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...   M    25
# 1   O871921  af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...   M    37
# 2    O10018  71162af7bf22799b776547132ebf134b5b438dcf3dac6b...   X  <NA>
# 3    O10038  c21c476e2ccc41af550b5d858d22aaac4ffc88745a1700...   X  <NA>
# 4    O10039  eb390a4c8e114c69488f5fb8a097fe629f5a92fd528cf4...   X  <NA>
#
#    SAFETY_EQUIPMENT    INJURY_CLASSIFICATION        BAC_RESULT
# 0      NONE PRESENT  NO INDICATION OF INJURY  TEST NOT OFFERED
# 1  SAFETY BELT USED  NO INDICATION OF INJURY  TEST NOT OFFERED
# 2     USAGE UNKNOWN  NO INDICATION OF INJURY  TEST NOT OFFERED
# 3     USAGE UNKNOWN  NO INDICATION OF INJURY  TEST NOT OFFERED
# 4     USAGE UNKNOWN  NO INDICATION OF INJURY  TEST NOT OFFERED

# %%
transformedDf1 = transformedDf1.dropna()

# %%
transformedDf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1139256 entries, 0 to 1955049
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   PERSON_ID              1139256 non-null  object
#  1   CRASH_RECORD_ID        1139256 non-null  object
#  2   SEX                    1139256 non-null  object
#  3   AGE                    1139256 non-null  Int64
#  4   SAFETY_EQUIPMENT       1139256 non-null  object
#  5   INJURY_CLASSIFICATION  1139256 non-null  object
#  6   BAC_RESULT             1139256 non-null  object
# dtypes: Int64(1), object(6)
# memory usage: 70.6+ MB

# %%
transformedDf1.head()
# Out:
#    PERSON_ID                                    CRASH_RECORD_ID SEX  AGE  \
# 0    O749947  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...   M   25
# 1    O871921  af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...   M   37
# 12   O848601  f25f09798b51603bde602ded37fea826fc8b7f962fc3b0...   F   34
# 13   O877654  e9146986f4b0884d00ff3a54da5249263b4b36c15d01ce...   M   53
# 14   O879085  f15ccbd94a8e29ce8424882ce93061d4e1d0deb214acfe...   M   65
#
#     SAFETY_EQUIPMENT    INJURY_CLASSIFICATION        BAC_RESULT
# 0       NONE PRESENT  NO INDICATION OF INJURY  TEST NOT OFFERED
# 1   SAFETY BELT USED  NO INDICATION OF INJURY  TEST NOT OFFERED
# 12  SAFETY BELT USED  NO INDICATION OF INJURY  TEST NOT OFFERED
# 13  SAFETY BELT USED  NO INDICATION OF INJURY  TEST NOT OFFERED
# 14     USAGE UNKNOWN  NO INDICATION OF INJURY  TEST NOT OFFERED

# %%
import pandas as pd

# Replace 'your_path_here' with the path to your CSV file
file_path = "../data/Traffic_Crashes_-_Vehicles.csv"

# Read the CSV file
df2 = pd.read_csv(file_path)

# Display information about the DataFrame
df2.info()
# Out:
# C:\Users\ashee\AppData\Local\Temp\ipykernel_13616\550206504.py:7: DtypeWarning: Columns (20,39,40,41,43,47,48,49,52,54,57,58,60,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv(file_path)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1815924 entries, 0 to 1815923
# Data columns (total 71 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   CRASH_UNIT_ID             int64
#  1   CRASH_RECORD_ID           object
#  2   CRASH_DATE                object
#  3   UNIT_NO                   int64
#  4   UNIT_TYPE                 object
#  5   NUM_PASSENGERS            float64
#  6   VEHICLE_ID                float64
#  7   CMRC_VEH_I                object
#  8   MAKE                      object
#  9   MODEL                     object
#  10  LIC_PLATE_STATE           object
#  11  VEHICLE_YEAR              float64
#  12  VEHICLE_DEFECT            object
#  13  VEHICLE_TYPE              object
# ...

# %%
df2['CRASH_DATE'] = pd.to_datetime(df2['CRASH_DATE'], errors='coerce')
df2['NUM_PASSENGERS'] = df2['NUM_PASSENGERS'].astype('Int64')
df2['UNIT_TYPE'] = df2['UNIT_TYPE'].astype('category')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1815924 entries, 0 to 1815923
# Data columns (total 71 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   CRASH_UNIT_ID             int64
#  1   CRASH_RECORD_ID           object
#  2   CRASH_DATE                datetime64[ns]
#  3   UNIT_NO                   int64
#  4   UNIT_TYPE                 category
#  5   NUM_PASSENGERS            Int64
#  6   VEHICLE_ID                float64
#  7   CMRC_VEH_I                object
#  8   MAKE                      object
#  9   MODEL                     object
#  10  LIC_PLATE_STATE           object
#  11  VEHICLE_YEAR              float64
#  12  VEHICLE_DEFECT            object
#  13  VEHICLE_TYPE              object
#  14  VEHICLE_USE               object
#  15  TRAVEL_DIRECTION          object
#  16  MANEUVER                  object
#  17  TOWED_I                   object
#  18  FIRE_I                    object
# ...

# %%
transformedDf2 = df2[[
      "CRASH_RECORD_ID",
      "VEHICLE_ID",
      "VEHICLE_DEFECT",
      "MAKE",
      "MODEL",
      "VEHICLE_YEAR",
      "UNIT_TYPE",
      "OCCUPANT_CNT",
      "TRAVEL_DIRECTION"
    ]]
transformedDf2.head()
# Out:
#                                      CRASH_RECORD_ID  VEHICLE_ID  \
# 0  f5943b05f46b8d4148a63b7506a59113eae0cf1075aabc...         NaN
# 1  7b1763088507f77e0e552c009a6bf89a4d6330c7527706...   1634931.0
# 2  2603ff5a88f0b9b54576934c5ed4e4a64e8278e005687b...   1634978.0
# 3  a52ef70e33d468b855b5be44e8638a564434dcf99c0edf...   1634948.0
# 4  609055f4b1a72a44d6ec40ba9036cefd7c1287a755eb6c...   1637401.0
#
#   VEHICLE_DEFECT      MAKE    MODEL  VEHICLE_YEAR   UNIT_TYPE  OCCUPANT_CNT  \
# 0            NaN       NaN      NaN           NaN  PEDESTRIAN           NaN
# 1        UNKNOWN    NISSAN   SENTRA        2009.0      DRIVER           1.0
# 2           NONE  CHRYSLER  SEBRING        2010.0      DRIVER           1.0
# 3        UNKNOWN    SUBARU  OUTBACK        2015.0      DRIVER           1.0
# 4        UNKNOWN    TOYOTA     RAV4        2018.0      DRIVER           1.0
#
#   TRAVEL_DIRECTION
# 0              NaN
# 1                S
# 2                S
# 3                W
# ...

# %%
transformedDf2 = transformedDf2.dropna()
transformedDf2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1491134 entries, 1 to 1815923
# Data columns (total 9 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   CRASH_RECORD_ID   1491134 non-null  object
#  1   VEHICLE_ID        1491134 non-null  float64
#  2   VEHICLE_DEFECT    1491134 non-null  object
#  3   MAKE              1491134 non-null  object
#  4   MODEL             1491134 non-null  object
#  5   VEHICLE_YEAR      1491134 non-null  float64
#  6   UNIT_TYPE         1491134 non-null  category
#  7   OCCUPANT_CNT      1491134 non-null  float64
#  8   TRAVEL_DIRECTION  1491134 non-null  object
# dtypes: category(1), float64(3), object(5)
# memory usage: 103.8+ MB

# %%
transformedDf2.head()
# Out:
#                                      CRASH_RECORD_ID  VEHICLE_ID  \
# 1  7b1763088507f77e0e552c009a6bf89a4d6330c7527706...   1634931.0
# 2  2603ff5a88f0b9b54576934c5ed4e4a64e8278e005687b...   1634978.0
# 3  a52ef70e33d468b855b5be44e8638a564434dcf99c0edf...   1634948.0
# 4  609055f4b1a72a44d6ec40ba9036cefd7c1287a755eb6c...   1637401.0
# 5  609055f4b1a72a44d6ec40ba9036cefd7c1287a755eb6c...   1637408.0
#
#   VEHICLE_DEFECT      MAKE    MODEL  VEHICLE_YEAR UNIT_TYPE  OCCUPANT_CNT  \
# 1        UNKNOWN    NISSAN   SENTRA        2009.0    DRIVER           1.0
# 2           NONE  CHRYSLER  SEBRING        2010.0    DRIVER           1.0
# 3        UNKNOWN    SUBARU  OUTBACK        2015.0    DRIVER           1.0
# 4        UNKNOWN    TOYOTA     RAV4        2018.0    DRIVER           1.0
# 5           NONE    SUBARU  OUTBACK        2019.0    DRIVER           1.0
#
#   TRAVEL_DIRECTION
# 1                S
# 2                S
# 3                W
# 4                E
# 5                W

# %%
df2 = transformedDf2

# %%
import matplotlib.pyplot as plt
# Calculate total and null values for each column
total_values = df2.shape[0]
null_values = df2.isnull().sum()
non_null_values = total_values - null_values
# Print the total and null values for each column
column_info = pd.DataFrame({
    # 'Total Values': total_values,
    'Non-Null Values': non_null_values,
    'Null Values': null_values
})

# Set display options to show all rows
pd.set_option('display.max_rows', len(column_info))
print(column_info)
pd.reset_option('display.max_rows')  # Reset option after printing

# Select columns with the highest null values (top 15 for example)
top_null_columns = null_values.nlargest(15).index
top_non_null_values = non_null_values[top_null_columns]
top_null_values = null_values[top_null_columns]

# Plotting
fig, ax = plt.subplots(figsize=(12, 20))
x = df2.columns
ax.barh(x, non_null_values, color="skyblue", label="Non-null values")
ax.barh(x, null_values, left=non_null_values, color="salmon", label="Null values")
ax.set_xlabel("Count")
ax.set_ylabel("Columns")
ax.set_title("Total and Null Values in Each Column in db2")
ax.legend()

plt.tight_layout()
plt.show()
pd.reset_option('display.max_rows')
# Out:
#                   Non-Null Values  Null Values
# CRASH_RECORD_ID           1491134            0
# VEHICLE_ID                1491134            0
# VEHICLE_DEFECT            1491134            0
# MAKE                      1491134            0
# MODEL                     1491134            0
# VEHICLE_YEAR              1491134            0
# UNIT_TYPE                 1491134            0
# OCCUPANT_CNT              1491134            0
# TRAVEL_DIRECTION          1491134            0

# %%
import matplotlib.pyplot as plt
# Calculate total and null values for each column
total_values = df1.shape[0]
null_values = df1.isnull().sum()
non_null_values = total_values - null_values
# Print the total and null values for each column
# column_info = pd.DataFrame({
#     'Total Values': total_values,
#     'Non-Null Values': non_null_values,
#     'Null Values': null_values
# })
column_info = pd.DataFrame({
    'Total Values': total_values,
    'Non-Null Values': non_null_values,
    'Null Values': null_values
})

# Set display options to show all rows
pd.set_option('display.max_rows', len(column_info))
pd.reset_option('display.max_rows')  # Reset option after printing

print(column_info)

# Select columns with the highest null values (top 15 for example)
top_null_columns = null_values.nlargest(15).index
top_non_null_values = non_null_values[top_null_columns]
top_null_values = null_values[top_null_columns]

# Plotting
fig, ax = plt.subplots(figsize=(12, 20))
x = df1.columns
ax.barh(x, non_null_values, color="skyblue", label="Non-null values")
ax.barh(x, null_values, left=non_null_values, color="salmon", label="Null values")
ax.set_xlabel("Count")
ax.set_ylabel("Columns")
ax.set_title("Total and Null Values in Each Column in db1")
ax.legend()

plt.tight_layout()
plt.show()
pd.reset_option('display.max_rows')
# Out:
#                        Total Values  Non-Null Values  Null Values
# PERSON_ID                   1955138          1955138            0
# PERSON_TYPE                 1955138          1955138            0
# CRASH_RECORD_ID             1955138          1955138            0
# VEHICLE_ID                  1955138          1915016        40122
# CRASH_DATE                  1955138          1955138            0
# SEAT_NO                     1955138           395593      1559545
# CITY                        1955138          1422544       532594
# STATE                       1955138          1444171       510967
# ZIPCODE                     1955138          1308383       646755
# SEX                         1955138          1922267        32871
# AGE                         1955138          1385561       569577
# DRIVERS_LICENSE_STATE       1955138          1144088       811050
# DRIVERS_LICENSE_CLASS       1955138           951691      1003447
# ...

# %%
print
